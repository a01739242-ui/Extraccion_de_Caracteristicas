# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .xlsx sin indice
df_bitacoras= pd.read_csv('/Users/ximenamarin/Desktop/extraccion_caracteristicas/Extraccion_de_Caracteristicas/Actividad 4.1/Analisis GAC Full7agosto 2026(Bitacora de Piso).csv')

# %%
df_bitacoras.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 30 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Fecha                                       198 non-null    str
#  1   Nombre Cliente                              197 non-null    str
#  2   Telefono                                    0 non-null      float64
#  3   Asesor                                      196 non-null    str
#  4   Esatus Lead                                 197 non-null    str
#  5   PDM                                         234 non-null    bool
#  6   SDC                                         216 non-null    object
#  7   Estatus de SDC                              2 non-null      str
#  8   Venta                                       216 non-null    object
#  9   Temperatura                                 10 non-null     str
# ...

# %%
df_bitacoras.head()
# Out:
#         Fecha         Nombre Cliente   Telefono    Asesor  Esatus Lead    PDM  \
# 0  04/01/2025  Ubaldo Cruz Hernandez         NaN   Aurelio      Activo   True
# 1  04/01/2025          Olivia Cabello        NaN     Pedro      Activo  False
# 2  04/02/2025      Ana Laura Espinoza        NaN  Mauricio      Activo   True
# 3  04/02/2025          Elvis Sanchez         NaN   Aurelio      Activo  False
# 4  04/03/2025   Ariel Fernando López         NaN     Alan       Activo   True
#
#      SDC Estatus de SDC   Venta       Temperatura   ... Unnamed: 20  \
# 0  False             NaN  False   Lead InteresBajo  ...         NaN
# 1  False             NaN  False   Lead InteresBajo  ...         NaN
# 2   True       Analisis    True  Lead Interes Alto  ...         NaN
# 3  False             NaN  False   Lead InteresBajo  ...         NaN
# 4  False             NaN  False                NaN  ...         NaN
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# ...

# %%
#Obtengo un análisis univariado de las variables categóricas
Tabla_freq = df_bitacoras['Asesor '].value_counts().reset_index()
Tabla_freq
# Out:
#                   Asesor   count
# 0                 Aurelio     34
# 1                Mauricio     28
# 2                   Pedro     25
# 3                  Victor     16
# 4                   Alan      13
# 5         Pedro González      11
# 6          Aurelio Torres     10
# 7          Alan González       7
# 8                Ricardo       5
# 9                 Ricardo      5
# 10      Mauricio Vazquez       5
# 11                Victor       4
# 12                  Nancy      3
# 13        Aurelio Torres       3
# 14         Ricardo Silva       3
# 15                Eduardo      2
# 16          Alan González      2
# 17                   Casa      2
# 18         Alan Gonzalez       2
# 19            Marcos Coca      2
# 20                  Laura      1
# 21                AUrelio      1
# 22        Nancy OLascoaga      1
# 23                   Alan      1
# 24          Pedro Antonio      1
# 25  Victor Manuel Sanchez      1
# 26       Mauricio Vazquez      1
# ...

# %%
df_bitacoras.columns
# Out:
# Index(['Fecha', 'Nombre Cliente ', 'Telefono ', 'Asesor ', 'Esatus Lead',
#        'PDM', 'SDC', 'Estatus de SDC ', 'Venta', 'Temperatura ',
#        'Inter Gerente', '¿Por que no hubo prueba de manejo?',
#        '¿Por que no hubo Solicitud de credito?',
#        '¿Por que no hubo intervencion del Gerente?',
#        '¿Por que no hubo proceso wow?',
#        '¿Por que no se ha formalizado la compra?',
#        '5 porques clientes de piso ', 'Comentarios', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29'],
#       dtype='str')

# %%
Filtro= Tabla_freq[Tabla_freq['count']>=5]
Filtro
# Out:
#               Asesor   count
# 0             Aurelio     34
# 1            Mauricio     28
# 2               Pedro     25
# 3              Victor     16
# 4               Alan      13
# 5     Pedro González      11
# 6      Aurelio Torres     10
# 7      Alan González       7
# 8            Ricardo       5
# 9             Ricardo      5
# 10  Mauricio Vazquez       5

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('Asesor ')
Filtro_index
# Out:
#                    count
# Asesor
# Aurelio               34
# Mauricio              28
# Pedro                 25
# Victor                16
# Alan                  13
# Pedro González        11
# Aurelio Torres        10
# Alan González          7
# Ricardo                5
# Ricardo                5
# Mauricio Vazquez       5

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "red")
plt.title('Asesores con más de 4 Registros')
plt.xlabel('Asesor')
plt.ylabel('Cantidad de Ventas')
# Out:
# Text(0, 0.5, 'Cantidad de Ventas')

# %%
#Obtengo un análisis univariado de las variables categóricas
Tabla_freq1 = df_bitacoras['PDM'].value_counts().reset_index()
Tabla_freq1
# Out:
#      PDM  count
# 0  False    159
# 1   True     75

# %%
# Cambiamos las etiquetas
Tabla_freq1.index = Tabla_freq1.index.map({
    0: "Sin Prueba de Manejo",
    1: "Con Prueba de Manejo"
})

# %%
Tabla_freq1["count"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: >

# %%
valores_nulos = df_bitacoras.isnull().sum()
valores_nulos
# Out:
# Fecha                                          36
# Nombre Cliente                                 37
# Telefono                                      234
# Asesor                                         38
# Esatus Lead                                    37
# PDM                                             0
# SDC                                            18
# Estatus de SDC                                232
# Venta                                          18
# Temperatura                                   224
# Inter Gerente                                  18
# ¿Por que no hubo prueba de manejo?            218
# ¿Por que no hubo Solicitud de credito?        220
# ¿Por que no hubo intervencion del Gerente?    223
# ¿Por que no hubo proceso wow?                 222
# ¿Por que no se ha formalizado la compra?      223
# 5 porques clientes de piso                    226
# Comentarios                                   212
# Unnamed: 18                                   234
# ...

# %%
#Obtengo un análisis univariado de las variables categóricas
Tabla_freq2 = df_bitacoras['SDC'].value_counts().reset_index()
Tabla_freq2
# Out:
#      SDC  count
# 0  False    212
# 1   True      4

# %%
# Cambiamos las etiquetas
Tabla_freq2.index = Tabla_freq2.index.map({
    0: "Sin petición de financiamiento",
    1: "Con petición de financiamiento"
})

# %%
Tabla_freq2["count"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: >

# %%
#Obtengo un análisis univariado de las variables categóricas
Tabla_freq3 = df_bitacoras['Venta'].value_counts().reset_index()
Tabla_freq3
# Out:
#    Venta  count
# 0  False    212
# 1   True      4

# %%
# Cambiamos las etiquetas
Tabla_freq3.index = Tabla_freq3.index.map({
    0: "Sin venta",
    1: "Con venta"
})

# %%
Tabla_freq3["count"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: >

# %%
Tabla_freq5 = df_bitacoras['Inter Gerente'].value_counts().reset_index()
Tabla_freq5
# Out:
#    Inter Gerente  count
# 0          False    185
# 1           True     31

# %%
Tabla_freq5["Inter Gerente"] = Tabla_freq5["Inter Gerente"].replace({
    False: "Si intervino",
    True: "No intervino"
})
ax = Tabla_freq5.plot(
    kind="pie",
    y="count",
    labels=Tabla_freq5['Inter Gerente'],
    figsize=(8, 8),
    shadow=True,
    autopct="%0.1f%%",
    legend=False
)

ax.set_ylabel("")
ax.set_title("Intervención del Gerente en la Venta")
# Out:
# Text(0.5, 1.0, 'Intervención del Gerente en la Venta')

# %%
#Obtengo un análisis univariado de las variables categóricas
Tabla_freq6 = df_bitacoras['Esatus Lead'].value_counts().reset_index()
Tabla_freq6
# Out:
#    Esatus Lead  count
# 0       Activo    157
# 1      Cerrado     11
# 2      Activo      11
# 3     Cerrado       7
# 4       Venta       3
# 5        Venta      3
# 6   Finalizado      2
# 7  Finalizado       2
# 8        venta      1

# %%
# Limpio los valores
df_bitacoras["Esatus Lead"] = (
    df_bitacoras["Esatus Lead"]
    .str.strip()
    .str.capitalize()
)

# Creo la tabla de frecuencias
Tabla_freq7 = df_bitacoras["Esatus Lead"].value_counts().reset_index()
Tabla_freq7
# Out:
#   Esatus Lead  count
# 0      Activo    168
# 1     Cerrado     18
# 2       Venta      7
# 3  Finalizado      4

# %%
Tabla_freq7.plot(kind = 'bar', width=0.8, figsize=(10,4), color= "purple", edgecolor="black")
plt.title('Estatus Lead con más de 3 registros')
plt.xlabel('Estatus Lead')
plt.ylabel('Registros')
# Out:
# Text(0, 0.5, 'Registros')

# %%
 #Obtengo un análisis univariado de las variables categóricas
Tabla_freq6 = df_bitacoras['Fecha'].value_counts().reset_index()
Tabla_freq6
# Out:
#          Fecha  count
# 0   05/12/2025      6
# 1    5/17/2025      6
# 2   05/06/2025      5
# 3    5/30/2025      5
# 4    6/25/2025      5
# ..         ...    ...
# 84   6/22/2025      1
# 85   6/29/2025      1
# 86   6/30/2025      1
# 87  07/09/2025      1
# 88  08/01/2025      1
#
# [89 rows x 2 columns]

# %%
#Obtengo un filtro de los valores más reelevantes de la variable categórica seleccionada
Filtro2= Tabla_freq6[Tabla_freq6['count']>3] #Filtrar los que sean mayores a 3
Filtro2
# Out:
#          Fecha  count
# 0   05/12/2025      6
# 1    5/17/2025      6
# 2   05/06/2025      5
# 3    5/30/2025      5
# 4    6/25/2025      5
# 5   07/03/2025      5
# 6   04/02/2025      4
# 7    5/16/2025      4
# 8   06/06/2025      4
# 9   06/07/2025      4
# 10   6/20/2025      4
# 11   6/24/2025      4

# %%
#Ajusto el indice de mi dataframe
Filtro_index2= Filtro2.set_index('Fecha')
Filtro_index2
# Out:
#             count
# Fecha
# 05/12/2025      6
# 5/17/2025       6
# 05/06/2025      5
# 5/30/2025       5
# 6/25/2025       5
# 07/03/2025      5
# 04/02/2025      4
# 5/16/2025       4
# 06/06/2025      4
# 06/07/2025      4
# 6/20/2025       4
# 6/24/2025       4

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index2.plot(kind='area', figsize=(10,4),alpha = 1)
# Out:
# <Axes: xlabel='Fecha'>

# %%
# Extraigo la pregunta abierta
Pregunta_abierta = df_bitacoras[
    ["¿Por que no hubo prueba de manejo?"]
].copy()

# Elimino las respuestas vacías
Pregunta_abierta = Pregunta_abierta.dropna()

Pregunta_abierta
# Out:
#                    ¿Por que no hubo prueba de manejo?
# 0                           Sí hubo prueba de manejo.
# 1   La clienta piensa acudir con sus hijos para ha...
# 2   Sí hubo prueba de manejo por la tarde, ya que ...
# 3   El cliente no quiso porque sabe que no se encu...
# 6   Sí hubo prueba de manejo, el cliente quedo fas...
# 13  El cliente ya había realizado una prueba de ma...
# 18  Sí realizo prueba de manejo y se fue muy satis...
# 25  Porque el cliente va a comprar sin ver el vehí...
# 34  Sí hubo ya dos pruebas de manejo, en la primer...
# 35  La camioneta es para la esposa del cliente y p...
# 48                                    falta de tiempo
# 52                           No habia unidad para PDM
# 67         El cliente no desea hacer prueba de manejo
# 70            Falta de tiempo, no venia con su pareja
# 74                                    viene el sabado
# 75  Es la tercera vez que viene a la agencia, y no...

# %%
Pregunta_abierta["Caracteristica"] = "Otro"

Pregunta_abierta.loc[
    Pregunta_abierta["¿Por que no hubo prueba de manejo?"]
    .str.contains("tiempo", case=False),
    "Caracteristica"
] = "Falta de tiempo"

Pregunta_abierta.loc[
    Pregunta_abierta["¿Por que no hubo prueba de manejo?"]
    .str.contains("unidad", case=False),
    "Caracteristica"
] = "Unidad no disponible"

Pregunta_abierta.loc[
    Pregunta_abierta["¿Por que no hubo prueba de manejo?"]
    .str.contains("no desea|no quiso", case=False),
    "Caracteristica"
] = "Cliente no quiso"

Pregunta_abierta.loc[
    Pregunta_abierta["¿Por que no hubo prueba de manejo?"]
    .str.contains("sábado|acudir|domicilio", case=False),
    "Caracteristica"
] = "Prueba posterior"

Pregunta_abierta.loc[
    Pregunta_abierta["¿Por que no hubo prueba de manejo?"]
    .str.contains("sí hubo|sí realizo|ya.*prueba", case=False),
    "Caracteristica"
] = "Sí hubo prueba de manejo"

Pregunta_abierta
# Out:
#                    ¿Por que no hubo prueba de manejo?  \
# 0                           Sí hubo prueba de manejo.
# 1   La clienta piensa acudir con sus hijos para ha...
# 2   Sí hubo prueba de manejo por la tarde, ya que ...
# 3   El cliente no quiso porque sabe que no se encu...
# 6   Sí hubo prueba de manejo, el cliente quedo fas...
# 13  El cliente ya había realizado una prueba de ma...
# 18  Sí realizo prueba de manejo y se fue muy satis...
# 25  Porque el cliente va a comprar sin ver el vehí...
# 34  Sí hubo ya dos pruebas de manejo, en la primer...
# 35  La camioneta es para la esposa del cliente y p...
# 48                                    falta de tiempo
# 52                           No habia unidad para PDM
# 67         El cliente no desea hacer prueba de manejo
# 70            Falta de tiempo, no venia con su pareja
# 74                                    viene el sabado
# 75  Es la tercera vez que viene a la agencia, y no...
#
#               Caracteristica
# ...

# %%
Tabla_caracteristicas = (
    Pregunta_abierta["Caracteristica"]
    .value_counts()
    .reset_index()
)

Tabla_caracteristicas
# Out:
#              Caracteristica  count
# 0  Sí hubo prueba de manejo      6
# 1                      Otro      3
# 2          Prueba posterior      2
# 3          Cliente no quiso      2
# 4           Falta de tiempo      2
# 5      Unidad no disponible      1

# %%
#Realizamos grafico de pastel del dataframe filtrado
ax = Tabla_caracteristicas["count"].plot(
    kind="pie",
    labels=Tabla_caracteristicas["Caracteristica"],
    figsize=(10, 5),
    shadow=True,
    autopct="%0.1f%%",
    legend=False
)

ax.set_ylabel("")
ax.set_title("Motivos relacionados con la prueba de manejo")
# Out:
# Text(0.5, 1.0, 'Motivos relacionados con la prueba de manejo')
